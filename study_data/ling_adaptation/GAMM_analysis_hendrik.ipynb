# %%
# install.packages('stringr')
library(mgcv)
library(itsadug)
library(report)
library(xtable)
library(stringr)
packageVersion("mgcv") # make sure that this is at least 1.8.32
# Out:
# [1] ‘1.8.42’

# %%
#citation()

# %% [markdown]
# ## Analysis I: Label Changes

# %%
data = read.csv('data/label_changes.tsv',sep='\t')

# Decode B and M size strings, convert to millions
data$model_size <- str_replace(data$model_size, "175B", "175000000000")
data$model_size <- str_replace(data$model_size, "250M", "250000000")
data$model_size <- str_replace(data$model_size, "780M", "780000000")
data$model_size <- str_replace(data$model_size, "11B", "11000000000")
data$model_size <- str_replace(data$model_size, "20B", "20000000000")
data$model_size <- str_replace(data$model_size, "1.3B", "1300000000")
data$model_size <- str_replace(data$model_size, "30B", "30000000000")
data$model_size <- str_replace(data$model_size, "2.8B", "2800000000")
data$model_size <- str_replace(data$model_size, "6.9B", "6900000000")
data$model_size <- str_replace(data$model_size, "12B", "12000000000")
data$model_size <- str_replace(data$model_size, "3B", "3000000000")
data$model_size <- str_replace(data$model_size, "80M", "80000000")
data$model_size <- as.numeric(data$model_size)
data$log_model_size <- log10(data$model_size)
data$non_text_prompt_length <- data$mean_prompt_length - data$text_length

# set data types
data <- as.data.frame(unclass(data),
                      stringsAsFactors = TRUE)
#data$model_family <- relevel(data$model_family, ref="Flan-UL")
head(data)
summary(data)
# Out:
#   model_name       model_family model_size task     dataset
# 1 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 2 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 3 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 4 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 5 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 6 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
#   instance_id                     mean_prompt_length std_prompt_length
# 1 toxicity_diverse_perspectives_0 344.0               6.723095
# 2 toxicity_diverse_perspectives_1 385.8              15.778466
# 3 toxicity_diverse_perspectives_2 383.2              21.958142
# 4 toxicity_diverse_perspectives_3 420.0              14.505171
# 5 toxicity_diverse_perspectives_4 388.2              19.260322
# 6 toxicity_diverse_perspectives_5 428.6              14.677875
#   text_length label_change original_dispersion prompting_dispersion
# 1 31          0            0.7                 0
# 2 49          0            0.7                 0
# 3 57          0            0.4                 0
# 4 94          0            0.8                 0
# 5 50          1            0.8                 0
# 6 95          0            0.4                 0
#   log_model_size non_text_prompt_length
# 1 11.24304       313.0
# 2 11.24304       336.8
# 3 11.24304       326.2
# 4 11.24304       326.0
# 5 11.24304       338.2
# 6 11.24304       333.6
#                              model_name         model_family
#  allenai-tk-instruct-11b-def-pos  : 6999   Dolly-V2   :20997
#  allenai-tk-instruct-3b-def-pos   : 6999   Flan-T5    :34995
#  allenai-tk-instruct-base-def-pos : 6999   Flan-UL    : 6999
#  allenai-tk-instruct-large-def-pos: 6999   InstructGPT: 6999
#  allenai-tk-instruct-small-def-pos: 6999   OPT-IML    :13998
#  databricks-dolly-v2-12b          : 6999   Tk-Instruct:34995
#  (Other)                          :76989
#    model_size                task                       dataset
#  Min.   :8.000e+07   hatespeech:34000   diaz                :17000
#  1st Qu.:7.800e+08   sentiment :17000   diverse_perspectives:17000
#  Median :3.000e+09   stance    :33983   ghc                 :17000
#  Mean   :1.637e+10   toxicity  :34000   gwsd                :16983
#  3rd Qu.:1.100e+10                      jigsaw              :17000
#  Max.   :1.750e+11                      semeval2016t6       :17000
#                                         twitter             :17000
#              instance_id     mean_prompt_length std_prompt_length
#  hatespeech_ghc_0  :    17   Min.   : 238.2     Min.   : 0.6325
#  hatespeech_ghc_1  :    17   1st Qu.: 376.0     1st Qu.: 7.6837
#  hatespeech_ghc_10 :    17   Median : 416.2     Median :11.3031
#  hatespeech_ghc_100:    17   Mean   : 436.3     Mean   :12.0192
#  hatespeech_ghc_101:    17   3rd Qu.: 454.5     3rd Qu.:16.0947
#  hatespeech_ghc_102:    17   Max.   :1682.2     Max.   :28.7931
#  (Other)           :118881
#   text_length      label_change    original_dispersion prompting_dispersion
#  Min.   :   2.0   Min.   :0.0000   Min.   :0.0000      Min.   :0.0000
#  1st Qu.:  66.0   1st Qu.:0.0000   1st Qu.:0.0000      1st Qu.:0.0000
#  Median : 104.0   Median :0.0000   Median :0.4000      Median :0.0000
#  Mean   : 132.5   Mean   :0.2695   Mean   :0.3383      Mean   :0.1539
#  3rd Qu.: 137.0   3rd Qu.:1.0000   3rd Qu.:0.6000      3rd Qu.:0.4000
#  Max.   :1343.0   Max.   :1.0000   Max.   :1.0000      Max.   :1.0000
#
#  log_model_size   non_text_prompt_length
#  Min.   : 7.903   Min.   :227.2
#  1st Qu.: 8.892   1st Qu.:268.6
#  Median : 9.477   Median :307.4
#  Mean   : 9.407   Mean   :303.8
#  3rd Qu.:10.041   3rd Qu.:331.2
#  Max.   :11.243   Max.   :383.4

# %%
model_formula <- label_change ~ log_model_size +
                                text_length +
                                non_text_prompt_length +
                                model_family +
                                task +
                                # log_model_size:text_length +
                                # log_model_size:non_text_prompt_length +
                                # log_model_size:model_family +
                                # log_model_size:task +
                                # text_length:non_text_prompt_length +
                                # text_length:model_family +
                                # text_length:task +
                                # non_text_prompt_length:model_family +
                                # non_text_prompt_length:task +
                                # model_family:task +
                                s(dataset, bs = "re")
     
set.seed(0)
model <- bam(model_formula,
             data = data,
             family = binomial("logit"), # probit might also make sense: https://stats.stackexchange.com/questions/207625/how-to-choose-between-logit-probit-or-linear-probability-model
             method = "fREML",
             discrete = TRUE,
             select = TRUE,
             nthreads=12
             )


# Save the model and its dependencies
saveRDS(model, "models/model_zero_shot_aggregated.rds")
dependencies = c("mgcv")
file_obj <- file("models/model_zero_shot_aggregated.dep")
writeLines(dependencies, file_obj)
close(file_obj)

# Reports
summary(model)
# Out:
# Family: binomial
# Link function: logit
#
# Formula:
# label_change ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + s(dataset, bs = "re")
#
# Parametric coefficients:
#                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -7.0002730  0.3929682 -17.814  < 2e-16 ***
# log_model_size           0.5636220  0.0107101  52.625  < 2e-16 ***
# text_length             -0.0001690  0.0000632  -2.674  0.00749 **
# non_text_prompt_length   0.0015084  0.0009841   1.533  0.12536
# model_familyFlan-T5      0.5798300  0.0232562  24.932  < 2e-16 ***
# model_familyFlan-UL     -0.2057229  0.0324919  -6.332 2.43e-10 ***
# model_familyInstructGPT -1.9030611  0.0438200 -43.429  < 2e-16 ***
# model_familyOPT-IML     -0.6416911  0.0288353 -22.254  < 2e-16 ***
# model_familyTk-Instruct  0.3287518  0.0234349  14.028  < 2e-16 ***
# tasksentiment            0.6453996  0.4327956   1.491  0.13590
# taskstance              -0.0031370  0.3546622  -0.009  0.99294
# tasktoxicity             0.0898760  0.3516974   0.256  0.79830
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Approximate significance of smooth terms:
#              edf Ref.df Chi.sq p-value
# s(dataset) 2.949      6  479.6  <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# R-sq.(adj) =  0.0663   Deviance explained = 5.44%
# fREML = 1.7495e+05  Scale est. = 1         n = 118983

# %%
# Wald tests (same as summary() for smooth terms, but different output for parametric terms)
set.seed(0)
model_anova <- anova(model)
print(model_anova)
# Out:
# Family: binomial
# Link function: logit
#
# Formula:
# label_change ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + s(dataset, bs = "re")
#
# Parametric Terms:
#                        df   Chi.sq p-value
# log_model_size          1 2769.409 < 2e-16
# text_length             1    7.151 0.00749
# non_text_prompt_length  1    2.349 0.12536
# model_family            5 3937.765 < 2e-16
# task                    3    2.718 0.43710
#
# Approximate significance of smooth terms:
#              edf Ref.df Chi.sq p-value
# s(dataset) 2.949  6.000  479.6  <2e-16

# %%
print(xtable(model_anova$pTerms.table))
# Out:
# % latex table generated in R 4.2.3 by xtable 1.8-4 package
# % Fri Sep  8 12:10:02 2023
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrr}
#   \hline
#  & df & Chi.sq & p-value \\
#   \hline
# log\_model\_size & 1.00 & 2769.41 & 0.00 \\
#   text\_length & 1.00 & 7.15 & 0.01 \\
#   non\_text\_prompt\_length & 1.00 & 2.35 & 0.13 \\
#   model\_family & 5.00 & 3937.76 & 0.00 \\
#   task & 3.00 & 2.72 & 0.44 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
attributes(model_anova)
# Out:
# $names
#  [1] "p.coeff"       "se"            "p.t"           "p.pv"
#  [5] "residual.df"   "m"             "chi.sq"        "s.pv"
#  [9] "scale"         "r.sq"          "family"        "formula"
# [13] "n"             "dev.expl"      "edf"           "dispersion"
# [17] "pTerms.pv"     "pTerms.chi.sq" "pTerms.df"     "cov.unscaled"
# [21] "cov.scaled"    "p.table"       "pTerms.table"  "s.table"
# [25] "method"        "sp.criterion"  "rank"          "np"
#
# $class
# [1] "anova.gam"

# %%
print(report(model))
# Out:
# We fitted a logistic model (estimated using fREML and perf optimizer) to
# predict label_change with log_model_size, text_length, non_text_prompt_length,
# model_family, task and dataset (formula: label_change ~ log_model_size +
# text_length + non_text_prompt_length + model_family + task + s(dataset, bs =
# "re")). The model's explanatory power is weak (R2 = 0.07). The model's
# intercept, corresponding to log_model_size = 0, text_length = 0,
# non_text_prompt_length = 0, model_family = Dolly-V2, task = hatespeech and
# dataset = diaz, is at -7.00 (95% CI [-7.77, -6.23], p < .001). Within this
# model:
#
#   - The effect of log model size is statistically significant and positive (beta
# = 0.56, 95% CI [0.54, 0.58], p < .001; Std. beta = 0.51, 95% CI [0.49, 0.53])
#   - The effect of text length is statistically significant and negative (beta =
# -1.69e-04, 95% CI [-2.93e-04, -4.51e-05], p = 0.007; Std. beta = -0.02, 95% CI
# [-0.04, -6.04e-03])
#   - The effect of non text prompt length is statistically non-significant and
# positive (beta = 1.51e-03, 95% CI [-4.21e-04, 3.44e-03], p = 0.125; Std. beta =
# 0.05, 95% CI [-0.02, 0.12])
#   - The effect of model family [Flan-T5] is statistically significant and
# positive (beta = 0.58, 95% CI [0.53, 0.63], p < .001; Std. beta = 0.58, 95% CI
# [0.53, 0.63])
#   - The effect of model family [Flan-UL] is statistically significant and
# negative (beta = -0.21, 95% CI [-0.27, -0.14], p < .001; Std. beta = -0.21, 95%
# CI [-0.27, -0.14])
#   - The effect of model family [InstructGPT] is statistically significant and
# negative (beta = -1.90, 95% CI [-1.99, -1.82], p < .001; Std. beta = -1.90, 95%
# CI [-1.99, -1.82])
#   - The effect of model family [OPT-IML] is statistically significant and
# negative (beta = -0.64, 95% CI [-0.70, -0.59], p < .001; Std. beta = -0.64, 95%
# CI [-0.70, -0.59])
#   - The effect of model family [Tk-Instruct] is statistically significant and
# positive (beta = 0.33, 95% CI [0.28, 0.37], p < .001; Std. beta = 0.33, 95% CI
# [0.28, 0.37])
#   - The effect of task [sentiment] is statistically non-significant and positive
# (beta = 0.65, 95% CI [-0.20, 1.49], p = 0.136; Std. beta = 0.65, 95% CI [-0.20,
# 1.49])
#   - The effect of task [stance] is statistically non-significant and negative
# (beta = -3.14e-03, 95% CI [-0.70, 0.69], p = 0.993; Std. beta = -3.14e-03, 95%
# CI [-0.70, 0.69])
#   - The effect of task [toxicity] is statistically non-significant and positive
# (beta = 0.09, 95% CI [-0.60, 0.78], p = 0.798; Std. beta = 0.09, 95% CI [-0.60,
# 0.78])
#   - The effect of Smooth term (dataset) is statistically significant and NA (beta
# = , p < .001; Std. beta = , )
#
# Standardized parameters were obtained by fitting the model on a standardized
# version of the dataset.

# %%
wald_gam(model, comp=list(model_family=levels(data$model_family)))
# Out:
# Wald test
# -----
# model: label_change ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + s(dataset, bs = "re")
#
# Parametric effects:
#             (Intercept)          log_model_size             text_length
#           -7.0002729716            0.5636219729           -0.0001690126
#  non_text_prompt_length     model_familyFlan-T5     model_familyFlan-UL
#            0.0015083635            0.5798299732           -0.2057228758
# model_familyInstructGPT     model_familyOPT-IML model_familyTk-Instruct
#           -1.9030610798           -0.6416910976            0.3287517909
#           tasksentiment              taskstance            tasktoxicity
#            0.6453996440           -0.0031370190            0.0898760200
#
# Null hypothesis =  0
#
# Comparing Flan-T5 with InstructGPT (hatespeech):
# 	X2(1.000) = 3019.236, p < 2e-16 ***
#
# Comparing Dolly-V2 with InstructGPT (hatespeech):
# 	X2(1.000) = 1886.084, p < 2e-16 ***
#
# Comparing Flan-UL with InstructGPT (hatespeech):
# 	X2(1.000) = 1344.017, p < 2e-16 ***
#
# Comparing Flan-T5 with OPT-IML (hatespeech):
# 	X2(1.000) = 2044.886, p < 2e-16 ***
#
# Comparing Flan-T5 with Flan-UL (hatespeech):
# 	X2(1.000) = 609.202, p < 2e-16 ***
#
# Comparing Dolly-V2 with OPT-IML (hatespeech):
# 	X2(1.000) = 495.227, p < 2e-16 ***
#
# Comparing Flan-UL with OPT-IML (hatespeech):
# 	X2(1.000) = 158.221, p < 2e-16 ***
#
# Comparing Flan-T5 with Tk-Instruct (hatespeech):
# 	X2(1.000) = 212.835, p < 2e-16 ***
#
# Comparing Dolly-V2 with Flan-UL (hatespeech):
# 	X2(1.000) = 40.088, p = 2.43e-10 ***
#
# Comparing Dolly-V2 with Tk-Instruct (hatespeech):
# 	X2(1.000) = 196.793, p < 2e-16 ***
#
# Comparing Flan-UL with Tk-Instruct (hatespeech):
# 	X2(1.000) = 280.642, p < 2e-16 ***
#
# Comparing Dolly-V2 with Flan-T5 (hatespeech):
# 	X2(1.000) = 621.617, p < 2e-16 ***
#
# Comparing OPT-IML with Tk-Instruct (hatespeech):
# 	X2(1.000) = 1278.057, p < 2e-16 ***
#
# Comparing InstructGPT with OPT-IML (hatespeech):
# 	X2(1.000) = 782.730, p < 2e-16 ***
#
# Comparing InstructGPT with Tk-Instruct (hatespeech):
# 	X2(1.000) = 2442.250, p < 2e-16 ***

# %% [markdown]
# ## Analysis II: Zero Shot with Original Sociodemographic Profiles

# %%
data = read.csv('data/zero_shot_original_profiles.tsv',sep='\t')

# Decode B and M size strings, convert to millions
data$model_size <- str_replace(data$model_size, "175B", "175000000000")
data$model_size <- str_replace(data$model_size, "250M", "250000000")
data$model_size <- str_replace(data$model_size, "780M", "780000000")
data$model_size <- str_replace(data$model_size, "11B", "11000000000")
data$model_size <- str_replace(data$model_size, "20B", "20000000000")
data$model_size <- str_replace(data$model_size, "1.3B", "1300000000")
data$model_size <- str_replace(data$model_size, "30B", "30000000000")
data$model_size <- str_replace(data$model_size, "2.8B", "2800000000")
data$model_size <- str_replace(data$model_size, "6.9B", "6900000000")
data$model_size <- str_replace(data$model_size, "12B", "12000000000")
data$model_size <- str_replace(data$model_size, "3B", "3000000000")
data$model_size <- str_replace(data$model_size, "80M", "80000000")
data$model_size <- as.numeric(data$model_size)
data$log_model_size <- log10(data$model_size)
data$non_text_prompt_length <- data$prompt_length - data$text_length

# set data types
data <- as.data.frame(unclass(data),
                      stringsAsFactors = TRUE)
data$model_family <- relevel(data$model_family, ref="Flan-UL")

data$sd_prompting <- as.factor(data$sd_prompting) # needed for contrasts with condition

head(data)
summary(data)
# Out:
#   model_name       model_family model_size task     dataset
# 1 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 2 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 3 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 4 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 5 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 6 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
#   instance_id                       prompt_length text_length sd_prompting
# 1 toxicity_diverse_perspectives_0_0 349           31          1
# 2 toxicity_diverse_perspectives_0_0 229           31          0
# 3 toxicity_diverse_perspectives_0_1 354           31          1
# 4 toxicity_diverse_perspectives_0_1 229           31          0
# 5 toxicity_diverse_perspectives_0_2 336           31          1
# 6 toxicity_diverse_perspectives_0_2 229           31          0
#   correct_prediction original_dispersion log_model_size non_text_prompt_length
# 1 1                  0.7                 11.24304       318
# 2 1                  0.7                 11.24304       198
# 3 0                  0.7                 11.24304       323
# 4 0                  0.7                 11.24304       198
# 5 1                  0.7                 11.24304       305
# 6 1                  0.7                 11.24304       198
#                              model_name          model_family
#  allenai-tk-instruct-11b-def-pos  : 18452   Flan-UL    :18452
#  allenai-tk-instruct-3b-def-pos   : 18452   Dolly-V2   :55356
#  allenai-tk-instruct-base-def-pos : 18452   Flan-T5    :92260
#  allenai-tk-instruct-large-def-pos: 18452   InstructGPT:18452
#  allenai-tk-instruct-small-def-pos: 18452   OPT-IML    :36904
#  databricks-dolly-v2-12b          : 18452   Tk-Instruct:92260
#  (Other)                          :202972
#    model_size               task                        dataset
#  Min.   :8.000e+07   sentiment:143684   diaz                :143684
#  1st Qu.:7.800e+08   toxicity :170000   diverse_perspectives:170000
#  Median :3.000e+09
#  Mean   :1.637e+10
#  3rd Qu.:1.100e+10
#  Max.   :1.750e+11
#
#              instance_id     prompt_length     text_length     sd_prompting
#  sentiment_diaz_0_0:    34   Min.   : 205.0   Min.   :   7.0   0:156842
#  sentiment_diaz_0_1:    34   1st Qu.: 288.0   1st Qu.:  60.0   1:156842
#  sentiment_diaz_0_2:    34   Median : 367.0   Median :  91.0
#  sentiment_diaz_0_3:    34   Mean   : 367.8   Mean   : 104.3
#  sentiment_diaz_1_0:    34   3rd Qu.: 428.0   3rd Qu.: 130.0
#  sentiment_diaz_1_1:    34   Max.   :1704.0   Max.   :1343.0
#  (Other)           :313480
#  correct_prediction original_dispersion log_model_size   non_text_prompt_length
#  Min.   :0.0000     Min.   :0.0000      Min.   : 7.903   Min.   :197.0
#  1st Qu.:0.0000     1st Qu.:0.4688      1st Qu.: 8.892   1st Qu.:198.0
#  Median :0.0000     Median :0.6250      Median : 9.477   Median :251.0
#  Mean   :0.1641     Mean   :0.5882      Mean   : 9.407   Mean   :263.5
#  3rd Qu.:0.0000     3rd Qu.:0.7812      3rd Qu.:10.041   3rd Qu.:329.0
#  Max.   :1.0000     Max.   :1.0000      Max.   :11.243   Max.   :403.0

# %%
model_formula <- correct_prediction ~   log_model_size +
                                        text_length +
                                        non_text_prompt_length +
                                        model_family +
                                        task +
                                        sd_prompting +
                                        # log_model_size:text_length +
                                        # log_model_size:non_text_prompt_length +
                                        # log_model_size:model_family +
                                        # log_model_size:task +
                                        log_model_size:sd_prompting +
                                        # text_length:non_text_prompt_length +
                                        # text_length:model_family +
                                        # text_length:task +
                                        text_length:sd_prompting +
                                        # non_text_prompt_length:model_family +
                                        # non_text_prompt_length:task +
                                        non_text_prompt_length:sd_prompting +
                                        # model_family:task +
                                        model_family:sd_prompting +
                                        task:sd_prompting #+
                                        # s(dataset, bs = "re")

     
set.seed(0)
model <- bam(model_formula,
             data = data,
             family = binomial("logit"), # probit might also make sense: https://stats.stackexchange.com/questions/207625/how-to-choose-between-logit-probit-or-linear-probability-model
             method = "fREML",
             discrete = TRUE,
             select = TRUE,
             nthreads=1 # numeric issue with 12
             )


# Save the model and its dependencies
saveRDS(model, "models/model_zero_shot_original.rds")
dependencies = c("mgcv")
file_obj <- file("models/model_zero_shot_original.dep")
writeLines(dependencies, file_obj)
close(file_obj)

# Reports
summary(model)
# Out:
# Warning message in bam(model_formula, data = data, family = binomial("logit"), method = "fREML", :
# “keine Glätten, ignoriere 'discrete=TRUE'”
# Family: binomial
# Link function: logit
#
# Formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + sd_prompting + log_model_size:sd_prompting +
#     text_length:sd_prompting + non_text_prompt_length:sd_prompting +
#     model_family:sd_prompting + task:sd_prompting
#
# Parametric coefficients:
#                                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)                           -1.539e+01  1.447e+01  -1.064  0.28730
# log_model_size                        -7.696e-03  1.157e-02  -0.665  0.50606
# text_length                           -2.430e-04  7.334e-05  -3.314  0.00092
# non_text_prompt_length                -9.916e-03  1.046e-01  -0.095  0.92449
# model_familyDolly-V2                  -4.026e-01  3.530e-02 -11.407  < 2e-16
# model_familyFlan-T5                   -1.176e-01  3.607e-02  -3.261  0.00111
# model_familyInstructGPT                3.117e-01  4.253e-02   7.330 2.30e-13
# model_familyOPT-IML                    3.214e-01  3.625e-02   8.865  < 2e-16
# model_familyTk-Instruct               -3.235e-01  3.627e-02  -8.919  < 2e-16
# tasktoxicity                           1.687e+01  1.476e+01   1.143  0.25297
# sd_prompting1                          0.000e+00  0.000e+00     NaN      NaN
# log_model_size:sd_prompting1          -1.205e-01  1.693e-02  -7.114 1.13e-12
# text_length:sd_prompting1              6.946e-04  1.041e-04   6.674 2.50e-11
# non_text_prompt_length:sd_prompting1   8.735e-03  1.046e-01   0.083  0.93346
# model_familyDolly-V2:sd_prompting1    -8.498e-01  5.121e-02 -16.593  < 2e-16
# model_familyFlan-T5:sd_prompting1     -6.337e-01  5.130e-02 -12.353  < 2e-16
# model_familyInstructGPT:sd_prompting1 -1.620e-02  5.990e-02  -0.270  0.78682
# model_familyOPT-IML:sd_prompting1     -1.264e-01  5.089e-02  -2.485  0.01297
# model_familyTk-Instruct:sd_prompting1 -7.344e-01  5.181e-02 -14.175  < 2e-16
# tasktoxicity:sd_prompting1            -2.167e-01  2.071e+01  -0.010  0.99165
#
# (Intercept)
# log_model_size
# text_length                           ***
# non_text_prompt_length
# model_familyDolly-V2                  ***
# model_familyFlan-T5                   **
# model_familyInstructGPT               ***
# model_familyOPT-IML                   ***
# model_familyTk-Instruct               ***
# tasktoxicity
# sd_prompting1
# log_model_size:sd_prompting1          ***
# text_length:sd_prompting1             ***
# non_text_prompt_length:sd_prompting1
# model_familyDolly-V2:sd_prompting1    ***
# model_familyFlan-T5:sd_prompting1     ***
# model_familyInstructGPT:sd_prompting1
# model_familyOPT-IML:sd_prompting1     *
# model_familyTk-Instruct:sd_prompting1 ***
# tasktoxicity:sd_prompting1
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
# Rank: 19/20
# R-sq.(adj) =  0.194   Deviance explained = 27.6%
# -REML = 2.8842e+05  Scale est. = 1         n = 313684

# %%
# Wald tests (same as summary() for smooth terms, but different output for parametric terms)
set.seed(0)
model_anova <- anova(model)
print(model_anova)
# Out:
# Family: binomial
# Link function: logit
#
# Formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + sd_prompting + log_model_size:sd_prompting +
#     text_length:sd_prompting + non_text_prompt_length:sd_prompting +
#     model_family:sd_prompting + task:sd_prompting
#
# Parametric Terms:
#                                     df  Chi.sq  p-value
# log_model_size                       1   0.442  0.50606
# text_length                          1  10.982  0.00092
# non_text_prompt_length               1   0.009  0.92449
# model_family                         5 990.682  < 2e-16
# task                                 1   1.307  0.25297
# sd_prompting                         1     NaN      NaN
# log_model_size:sd_prompting          1  50.605 1.13e-12
# text_length:sd_prompting             1  44.537 2.50e-11
# non_text_prompt_length:sd_prompting  1   0.007  0.93346
# model_family:sd_prompting            5 561.327  < 2e-16
# task:sd_prompting                    1   0.000  0.99165

# %%
print(report(model))
# Out:
# We fitted a logistic model (estimated using REML and outer optimizer) to
# predict correct_prediction with log_model_size, text_length,
# non_text_prompt_length, model_family, task and sd_prompting (formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
# model_family + task + sd_prompting + log_model_size:sd_prompting +
# text_length:sd_prompting + non_text_prompt_length:sd_prompting +
# model_family:sd_prompting + task:sd_prompting). The model's explanatory power
# is moderate (R2 = 0.19). The model's intercept, corresponding to log_model_size
# = 0, text_length = 0, non_text_prompt_length = 0, model_family = Flan-UL, task
# = sentiment and sd_prompting = 0, is at -15.39 (95% CI [-43.75, 12.96], p =
# 0.287). Within this model:
#
#   - The effect of log model size is statistically non-significant and negative
# (beta = -7.70e-03, 95% CI [-0.03, 0.01], p = 0.506; Std. beta = -6.97e-03, 95%
# CI [-0.03, 0.01])
#   - The effect of text length is statistically significant and negative (beta =
# -2.43e-04, 95% CI [-3.87e-04, -9.93e-05], p < .001; Std. beta = -0.02, 95% CI
# [-0.03, -7.86e-03])
#   - The effect of non text prompt length is statistically non-significant and
# negative (beta = -9.92e-03, 95% CI [-0.21, 0.20], p = 0.924; Std. beta = -0.08,
# 95% CI [-0.15, -0.01])
#   - The effect of model family [Dolly-V2] is statistically significant and
# negative (beta = -0.40, 95% CI [-0.47, -0.33], p < .001; Std. beta = -0.40, 95%
# CI [-0.47, -0.33])
#   - The effect of model family [Flan-T5] is statistically significant and
# negative (beta = -0.12, 95% CI [-0.19, -0.05], p = 0.001; Std. beta = -0.12,
# 95% CI [-0.19, -0.05])
#   - The effect of model family [InstructGPT] is statistically significant and
# positive (beta = 0.31, 95% CI [0.23, 0.40], p < .001; Std. beta = 0.31, 95% CI
# [0.23, 0.40])
#   - The effect of model family [OPT-IML] is statistically significant and
# positive (beta = 0.32, 95% CI [0.25, 0.39], p < .001; Std. beta = 0.32, 95% CI
# [0.25, 0.39])
#   - The effect of model family [Tk-Instruct] is statistically significant and
# negative (beta = -0.32, 95% CI [-0.39, -0.25], p < .001; Std. beta = -0.32, 95%
# CI [-0.39, -0.25])
#   - The effect of task [toxicity] is statistically non-significant and positive
# (beta = 16.87, 95% CI [-12.05, 45.79], p = 0.253; Std. beta = 16.84, 95% CI
# [-11.60, 45.27])
#   - The effect of sd prompting [1] is statistically NA and positive (beta = 0.00,
# 95% CI [0.00, 0.00]; Std. beta = 0.65, 95% CI [-39.37, 40.67])
#   - The effect of log model size × sd prompting [1] is statistically significant
# and negative (beta = -0.12, 95% CI [-0.15, -0.09], p < .001; Std. beta = -0.11,
# 95% CI [-0.14, -0.08])
#   - The effect of text length × sd prompting [1] is statistically significant and
# positive (beta = 6.95e-04, 95% CI [4.91e-04, 8.99e-04], p < .001; Std. beta =
# 0.05, 95% CI [0.04, 0.07])
#   - The effect of non text prompt length × sd prompting [1] is statistically
# non-significant and positive (beta = 8.74e-03, 95% CI [-0.20, 0.21], p = 0.933;
# Std. beta = 0.00, 95% CI [0.00, 0.00])
#   - The effect of model family [Dolly-V2] × sd prompting [1] is statistically
# significant and negative (beta = -0.85, 95% CI [-0.95, -0.75], p < .001; Std.
# beta = -0.85, 95% CI [-0.95, -0.75])
#   - The effect of model family [Flan-T5] × sd prompting [1] is statistically
# significant and negative (beta = -0.63, 95% CI [-0.73, -0.53], p < .001; Std.
# beta = -0.63, 95% CI [-0.73, -0.53])
#   - The effect of model family [InstructGPT] × sd prompting [1] is statistically
# non-significant and negative (beta = -0.02, 95% CI [-0.13, 0.10], p = 0.787;
# Std. beta = -0.02, 95% CI [-0.13, 0.10])
#   - The effect of model family [OPT-IML] × sd prompting [1] is statistically
# significant and negative (beta = -0.13, 95% CI [-0.23, -0.03], p = 0.013; Std.
# beta = -0.13, 95% CI [-0.23, -0.03])
#   - The effect of model family [Tk-Instruct] × sd prompting [1] is statistically
# significant and negative (beta = -0.73, 95% CI [-0.84, -0.63], p < .001; Std.
# beta = -0.73, 95% CI [-0.84, -0.63])
#   - The effect of task [toxicity] × sd prompting [1] is statistically
# non-significant and negative (beta = -0.22, 95% CI [-40.82, 40.38], p = 0.992;
# Std. beta = -0.20, 95% CI [-40.22, 39.82])
#
# Standardized parameters were obtained by fitting the model on a standardized
# version of the dataset.

# %%
print(xtable(model_anova$pTerms.table))
# Out:
# % latex table generated in R 4.2.3 by xtable 1.8-4 package
# % Fri Sep  8 17:32:58 2023
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrr}
#   \hline
#  & df & Chi.sq & p-value \\
#   \hline
# log\_model\_size & 1.00 & 0.44 & 0.51 \\
#   text\_length & 1.00 & 10.98 & 0.00 \\
#   non\_text\_prompt\_length & 1.00 & 0.01 & 0.92 \\
#   model\_family & 5.00 & 990.68 & 0.00 \\
#   task & 1.00 & 1.31 & 0.25 \\
#   sd\_prompting & 1.00 &  &  \\
#   log\_model\_size:sd\_prompting & 1.00 & 50.61 & 0.00 \\
#   text\_length:sd\_prompting & 1.00 & 44.54 & 0.00 \\
#   non\_text\_prompt\_length:sd\_prompting & 1.00 & 0.01 & 0.93 \\
#   model\_family:sd\_prompting & 5.00 & 561.33 & 0.00 \\
#   task:sd\_prompting & 1.00 & 0.00 & 0.99 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
length(c(1,1,1,1,1,1,1))
# Out:
# [1] 7

# %%
# wald_gam(model, comp=list(model_family=levels(data$model_family)))
wald_gam(model, comp=list(model_family=levels(data$model_family), sd_prompting=1))
# Out:
# Wald test
# -----
# model: correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + sd_prompting + log_model_size:sd_prompting +
#     text_length:sd_prompting + non_text_prompt_length:sd_prompting +
#     model_family:sd_prompting + task:sd_prompting
#
# Parametric effects:
#                           (Intercept)                        log_model_size
#                         -1.539296e+01                         -7.695731e-03
#                           text_length                non_text_prompt_length
#                         -2.430420e-04                         -9.915878e-03
#                  model_familyDolly-V2                   model_familyFlan-T5
#                         -4.026125e-01                         -1.176128e-01
#               model_familyInstructGPT                   model_familyOPT-IML
#                          3.117347e-01                          3.213956e-01
#               model_familyTk-Instruct                          tasktoxicity
#                         -3.235420e-01                          1.686874e+01
#                         sd_prompting1          log_model_size:sd_prompting1
#                          0.000000e+00                         -1.204502e-01
#             text_length:sd_prompting1  non_text_prompt_length:sd_prompting1
#                          6.946503e-04                          8.735084e-03
#    model_familyDolly-V2:sd_prompting1     model_familyFlan-T5:sd_prompting1
#                         -8.497549e-01                         -6.337228e-01
# model_familyInstructGPT:sd_prompting1     model_familyOPT-IML:sd_prompting1
#                         -1.619942e-02                         -1.264450e-01
# model_familyTk-Instruct:sd_prompting1            tasktoxicity:sd_prompting1
#                         -7.343675e-01                         -2.167453e-01
#
# Null hypothesis =  0
#
# Comparing InstructGPT.1 with Tk-Instruct.1 (toxicity):
# 	X2(1.000) = 972.032, p < 2e-16 ***
#
# Comparing OPT-IML.1 with Tk-Instruct.1 (toxicity):
# 	X2(1.000) = 2065.827, p < 2e-16 ***
#
# Comparing Flan-UL.1 with Dolly-V2.1 (toxicity):
# 	X2(1.000) = 1139.083, p < 2e-16 ***
#
# Comparing Flan-UL.1 with Tk-Instruct.1 (toxicity):
# 	X2(1.000) = 817.991, p < 2e-16 ***
#
# Comparing Flan-UL.1 with Flan-T5.1 (toxicity):
# 	X2(1.000) = 424.222, p < 2e-16 ***
#
# Comparing Flan-T5.1 with Tk-Instruct.1 (toxicity):
# 	X2(1.000) = 214.942, p < 2e-16 ***
#
# Comparing InstructGPT.1 with OPT-IML.1 (toxicity):
# 	X2(1.000) = 6.588, p = 0.010 *
#
# Comparing Dolly-V2.1 with Tk-Instruct.1 (toxicity):
# 	X2(1.000) = 44.079, p = 3.15e-11 ***
#
# Comparing Flan-UL.1 with OPT-IML.1 (toxicity):
# 	X2(1.000) = 29.792, p = 4.81e-08 ***
#
# Comparing Flan-UL.1 with InstructGPT.1 (toxicity):
# 	X2(1.000) = 49.087, p = 2.45e-12 ***
#
# Comparing Dolly-V2.1 with Flan-T5.1 (toxicity):
# 	X2(1.000) = 305.575, p < 2e-16 ***
#
# Comparing Flan-T5.1 with OPT-IML.1 (toxicity):
# 	X2(1.000) = 1237.527, p < 2e-16 ***
#
# Comparing Flan-T5.1 with InstructGPT.1 (toxicity):
# 	X2(1.000) = 594.125, p < 2e-16 ***
#
# Comparing Dolly-V2.1 with OPT-IML.1 (toxicity):
# 	X2(1.000) = 2312.777, p < 2e-16 ***
#
# Comparing Dolly-V2.1 with InstructGPT.1 (toxicity):
# 	X2(1.000) = 1461.654, p < 2e-16 ***

# %%
plot_diff(model, view="log_model_size",
            comp=list(sd_prompting=c(1,0)),
            col="red",
            rug=FALSE,
            #add=TRUE,
            rm.ranef=TRUE)
# Out:
# Summary:
# 	* log_model_size : numeric predictor; with 100 values ranging from 7.903090 to 11.243038.
# 	* text_length : numeric predictor; set to the value(s): 91.
# 	* non_text_prompt_length : numeric predictor; set to the value(s): 198.
# 	* model_family : factor; set to the value(s): Flan-T5.
# 	* task : factor; set to the value(s): toxicity.
# 	* NOTE : No random effects in the model to cancel.
# Warning message in plot.window(...):
# “"rug" ist kein Grafikparameter”
# Warning message in plot.xy(xy, type, ...):
# “"rug" ist kein Grafikparameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"rug" ist kein Grafikparameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"rug" ist kein Grafikparameter”
# Warning message in box(...):
# “"rug" ist kein Grafikparameter”
# Warning message in title(...):
# “"rug" ist kein Grafikparameter”
# log_model_size window(s) of significant difference(s):
# 	8.982669 - 11.243038
# Plot with title “Difference 1 - 0”

# %%
plot_diff(model, view="text_length",
            comp=list(sd_prompting=c(1,0)),
            col="red",
            rug=FALSE,
            #add=TRUE,
            rm.ranef=TRUE)
# Out:
# Summary:
# 	* log_model_size : numeric predictor; set to the value(s): 9.47712125471966.
# 	* text_length : numeric predictor; with 100 values ranging from 7.000000 to 1343.000000.
# 	* non_text_prompt_length : numeric predictor; set to the value(s): 198.
# 	* model_family : factor; set to the value(s): Flan-T5.
# 	* task : factor; set to the value(s): toxicity.
# 	* NOTE : No random effects in the model to cancel.
# Warning message in plot.window(...):
# “"rug" ist kein Grafikparameter”
# Warning message in plot.xy(xy, type, ...):
# “"rug" ist kein Grafikparameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"rug" ist kein Grafikparameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"rug" ist kein Grafikparameter”
# Warning message in box(...):
# “"rug" ist kein Grafikparameter”
# Warning message in title(...):
# “"rug" ist kein Grafikparameter”
# text_length window(s) of significant difference(s):
# 	7.000000 - 168.939394
# 	641.262626 - 1343.000000
# Plot with title “Difference 1 - 0”

# %%
plot_parametric(model,  pred=list(model_family=levels(data$model_family)), cond=list(sd_prompting=c(1)),
    rm.ranef = TRUE)
# Out:
# Summary:
# 	* log_model_size : numeric predictor; set to the value(s): 9.47712125471966.
# 	* text_length : numeric predictor; set to the value(s): 91.
# 	* non_text_prompt_length : numeric predictor; set to the value(s): 198.
# 	* model_family : factor; set to the value(s): Dolly-V2, Flan-T5, Flan-UL, InstructGPT, OPT-IML, Tk-Instruct.
# 	* task : factor; set to the value(s): toxicity.
# 	* sd_prompting : numeric predictor; set to the value(s): 1.
# 	* NOTE : No random effects in the model to cancel.
# Plot with title “model_family”

# %% [markdown]
# ## Analysis III: Zero Shot with Aggregated Predictions

# %% [markdown]
# ### Data Loading

# %%
data = read.csv('data/zero_shot_aggregated_profiles.tsv',sep='\t')

# Decode B and M size strings, convert to millions
data$model_size <- str_replace(data$model_size, "175B", "175000000000")
data$model_size <- str_replace(data$model_size, "250M", "250000000")
data$model_size <- str_replace(data$model_size, "780M", "780000000")
data$model_size <- str_replace(data$model_size, "11B", "11000000000")
data$model_size <- str_replace(data$model_size, "20B", "20000000000")
data$model_size <- str_replace(data$model_size, "1.3B", "1300000000")
data$model_size <- str_replace(data$model_size, "30B", "30000000000")
data$model_size <- str_replace(data$model_size, "2.8B", "2800000000")
data$model_size <- str_replace(data$model_size, "6.9B", "6900000000")
data$model_size <- str_replace(data$model_size, "12B", "12000000000")
data$model_size <- str_replace(data$model_size, "3B", "3000000000")
data$model_size <- str_replace(data$model_size, "80M", "80000000")
data$model_size <- as.numeric(data$model_size)
data$log_model_size <- log10(data$model_size)
data$non_text_prompt_length <- data$mean_prompt_length - data$text_length

# set data types
data <- as.data.frame(unclass(data),
                      stringsAsFactors = TRUE)
# TODO: Make sure that the reference level for the binary variables is set correctly!
#data$sd_prompting <- as.factor(data$sd_prompting)
#data$sd_prompting <- relevel(data$sd_prompting, ref='0')

# This is needed to set the reference level in case there is a natural baseline level for a variable
#data$model_family <- relevel(data$model_family, ref=tail(names(sort(table(data$model_family))), 1))
data$sd_prompting <- as.factor(data$sd_prompting) # needed for contrasts with condition
data$model_family <- relevel(data$model_family, ref="Flan-UL")

# %%
head(data)
summary(data)
# Out:
#   model_name       model_family model_size task     dataset
# 1 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 2 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 3 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 4 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 5 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 6 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
#   instance_id                     mean_prompt_length std_prompt_length
# 1 toxicity_diverse_perspectives_0 229                0
# 2 toxicity_diverse_perspectives_1 247                0
# 3 toxicity_diverse_perspectives_2 255                0
# 4 toxicity_diverse_perspectives_3 292                0
# 5 toxicity_diverse_perspectives_4 248                0
# 6 toxicity_diverse_perspectives_5 293                0
#   text_length sd_prompting correct_prediction original_dispersion
# 1 31          0            1                  0.7
# 2 49          0            1                  0.7
# 3 57          0            1                  0.4
# 4 94          0            0                  0.8
# 5 50          0            0                  0.8
# 6 95          0            1                  0.4
#   log_model_size non_text_prompt_length
# 1 11.24304       198
# 2 11.24304       198
# 3 11.24304       198
# 4 11.24304       198
# 5 11.24304       198
# 6 11.24304       198
#                              model_name          model_family
#  allenai-tk-instruct-11b-def-pos  : 13998   Flan-UL    :13998
#  allenai-tk-instruct-3b-def-pos   : 13998   Dolly-V2   :41994
#  allenai-tk-instruct-base-def-pos : 13998   Flan-T5    :69990
#  allenai-tk-instruct-large-def-pos: 13998   InstructGPT:13998
#  allenai-tk-instruct-small-def-pos: 13998   OPT-IML    :27996
#  databricks-dolly-v2-12b          : 13998   Tk-Instruct:69990
#  (Other)                          :153978
#    model_size                task                       dataset
#  Min.   :8.000e+07   hatespeech:68000   diaz                :34000
#  1st Qu.:7.800e+08   sentiment :34000   diverse_perspectives:34000
#  Median :3.000e+09   stance    :67966   ghc                 :34000
#  Mean   :1.637e+10   toxicity  :68000   gwsd                :33966
#  3rd Qu.:1.100e+10                      jigsaw              :34000
#  Max.   :1.750e+11                      semeval2016t6       :34000
#                                         twitter             :34000
#              instance_id     mean_prompt_length std_prompt_length
#  hatespeech_ghc_0  :    34   Min.   : 118.0     Min.   : 0.0000
#  hatespeech_ghc_1  :    34   1st Qu.: 282.0     1st Qu.: 0.0000
#  hatespeech_ghc_10 :    34   Median : 353.2     Median : 0.3162
#  hatespeech_ghc_100:    34   Mean   : 369.7     Mean   : 6.0096
#  hatespeech_ghc_101:    34   3rd Qu.: 426.6     3rd Qu.:11.3031
#  hatespeech_ghc_102:    34   Max.   :1682.2     Max.   :28.7931
#  (Other)           :237762
#   text_length     sd_prompting correct_prediction original_dispersion
#  Min.   :   2.0   0:118983     Min.   :0.0000     Min.   :0.0000
#  1st Qu.:  66.0   1:118983     1st Qu.:0.0000     1st Qu.:0.0000
#  Median : 104.0                Median :0.0000     Median :0.4000
#  Mean   : 132.5                Mean   :0.3883     Mean   :0.3859
#  3rd Qu.: 137.0                3rd Qu.:1.0000     3rd Qu.:0.7031
#  Max.   :1343.0                Max.   :1.0000     Max.   :1.0000
#
#  log_model_size   non_text_prompt_length
#  Min.   : 7.903   Min.   :114.0
#  1st Qu.: 8.892   1st Qu.:171.0
#  Median : 9.477   Median :223.6
#  Mean   : 9.407   Mean   :237.2
#  3rd Qu.:10.041   3rd Qu.:307.4
#  Max.   :11.243   Max.   :383.4

# %% [markdown]
# ### GAMM

# %%
model_formula <- correct_prediction ~   log_model_size +
                                        text_length +
                                        non_text_prompt_length +
                                        model_family +
                                        task +
                                        sd_prompting +
                                        # log_model_size:text_length +
                                        # log_model_size:non_text_prompt_length +
                                        # log_model_size:model_family +
                                        # log_model_size:task +
                                        log_model_size:sd_prompting +
                                        # text_length:non_text_prompt_length +
                                        # text_length:model_family +
                                        # text_length:task +
                                        text_length:sd_prompting +
                                        # non_text_prompt_length:model_family +
                                        # non_text_prompt_length:task +
                                        non_text_prompt_length:sd_prompting +
                                        # model_family:task +
                                        model_family:sd_prompting +
                                        task:sd_prompting +
                                        s(dataset, bs = "re")
     
set.seed(0)
model <- bam(model_formula,
             data = data,
             family = binomial("logit"), # probit might also make sense: https://stats.stackexchange.com/questions/207625/how-to-choose-between-logit-probit-or-linear-probability-model
             method = "fREML",
             discrete = TRUE,
             select = TRUE,
             nthreads=12
             )


# Save the model and its dependencies
saveRDS(model, "models/model_zero_shot_aggregated.rds")
dependencies = c("mgcv")
file_obj <- file("models/model_zero_shot_aggregated.dep")
writeLines(dependencies, file_obj)
close(file_obj)

# Reports
summary(model)
# Out:
# Family: binomial
# Link function: logit
#
# Formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + sd_prompting + log_model_size:sd_prompting +
#     text_length:sd_prompting + non_text_prompt_length:sd_prompting +
#     model_family:sd_prompting + task:sd_prompting + s(dataset,
#     bs = "re")
#
# Parametric coefficients:
#                                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)                           -6.916e-01  2.887e-01  -2.396 0.016584
# log_model_size                         1.712e-02  9.737e-03   1.758 0.078758
# text_length                            1.285e-04  5.073e-05   2.534 0.011291
# non_text_prompt_length                -8.383e-04  9.201e-04  -0.911 0.362248
# model_familyDolly-V2                  -1.212e-01  3.188e-02  -3.801 0.000144
# model_familyFlan-T5                    2.094e-01  3.234e-02   6.474 9.53e-11
# model_familyInstructGPT                1.659e+00  3.893e-02  42.632  < 2e-16
# model_familyOPT-IML                    1.257e+00  3.280e-02  38.317  < 2e-16
# model_familyTk-Instruct                7.874e-01  3.214e-02  24.494  < 2e-16
# tasksentiment                         -1.630e+00  4.056e-01  -4.017 5.89e-05
# taskstance                            -2.919e-01  3.318e-01  -0.880 0.379053
# tasktoxicity                          -1.077e-01  3.290e-01  -0.327 0.743495
# sd_prompting1                          1.319e+00  1.957e-01   6.738 1.61e-11
# log_model_size:sd_prompting1          -7.565e-02  1.380e-02  -5.481 4.23e-08
# text_length:sd_prompting1              1.190e-04  7.118e-05   1.671 0.094670
# non_text_prompt_length:sd_prompting1  -1.709e-03  3.299e-04  -5.180 2.22e-07
# model_familyDolly-V2:sd_prompting1    -2.202e-01  4.605e-02  -4.781 1.74e-06
# model_familyFlan-T5:sd_prompting1     -2.635e-01  4.573e-02  -5.762 8.30e-09
# model_familyInstructGPT:sd_prompting1  5.953e-02  5.479e-02   1.087 0.277231
# model_familyOPT-IML:sd_prompting1      1.231e-02  4.620e-02   0.266 0.789862
# model_familyTk-Instruct:sd_prompting1 -1.951e-01  4.534e-02  -4.303 1.69e-05
# tasksentiment:sd_prompting1            5.750e-01  3.725e-02  15.436  < 2e-16
# taskstance:sd_prompting1               1.674e-01  2.795e-02   5.989 2.11e-09
# tasktoxicity:sd_prompting1            -5.572e-02  2.422e-02  -2.301 0.021409
#
# (Intercept)                           *
# log_model_size                        .
# text_length                           *
# non_text_prompt_length
# model_familyDolly-V2                  ***
# model_familyFlan-T5                   ***
# model_familyInstructGPT               ***
# model_familyOPT-IML                   ***
# model_familyTk-Instruct               ***
# tasksentiment                         ***
# taskstance
# tasktoxicity
# sd_prompting1                         ***
# log_model_size:sd_prompting1          ***
# text_length:sd_prompting1             .
# non_text_prompt_length:sd_prompting1  ***
# model_familyDolly-V2:sd_prompting1    ***
# model_familyFlan-T5:sd_prompting1     ***
# model_familyInstructGPT:sd_prompting1
# model_familyOPT-IML:sd_prompting1
# model_familyTk-Instruct:sd_prompting1 ***
# tasksentiment:sd_prompting1           ***
# taskstance:sd_prompting1              ***
# tasktoxicity:sd_prompting1            *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Approximate significance of smooth terms:
#              edf Ref.df Chi.sq p-value
# s(dataset) 2.958      3   1205  <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# R-sq.(adj) =   0.12   Deviance explained =    9%
# fREML = 3.6344e+05  Scale est. = 1         n = 237966

# %%
# print(concurvity(model, full = FALSE))

# %%
# Wald tests (same as summary() for smooth terms, but different output for parametric terms)
set.seed(0)
model_anova <- anova(model)
print(model_anova)
# Out:
# Family: binomial
# Link function: logit
#
# Formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + sd_prompting + log_model_size:sd_prompting +
#     text_length:sd_prompting + non_text_prompt_length:sd_prompting +
#     model_family:sd_prompting + task:sd_prompting + s(dataset,
#     bs = "re")
#
# Parametric Terms:
#                                     df   Chi.sq  p-value
# log_model_size                       1    3.090 0.078758
# text_length                          1    6.419 0.011291
# non_text_prompt_length               1    0.830 0.362248
# model_family                         5 6470.727  < 2e-16
# task                                 3   18.312 0.000379
# sd_prompting                         1   45.399 1.61e-11
# log_model_size:sd_prompting          1   30.040 4.23e-08
# text_length:sd_prompting             1    2.793 0.094670
# non_text_prompt_length:sd_prompting  1   26.836 2.22e-07
# model_family:sd_prompting            5  101.286  < 2e-16
# task:sd_prompting                    3  309.459  < 2e-16
#
# Approximate significance of smooth terms:
#              edf Ref.df Chi.sq p-value
# s(dataset) 2.958  3.000   1205  <2e-16

# %%
# LateX tables
#anova_parametric <- model_anova$pTerms.table
#print(xtable(anova_parametric, type = "latex",
#            label="",
#            caption="Statistics for zero shot with original sociodemographic profiles: parametric terms"),
#      #file = "tables/gamm_correctness_zero_shot_original_parametric.tex"
#     )

# %%
#anova_smooth <- model_anova$s.table
#print(xtable(anova_smooth, type = "latex",
#            label="",
#            caption="Statistics for zero shot with original sociodemographic profiles: smooth terms"),
#      #file = "tables/gamm_correctness_zero_shot_original_smooth.tex"
#     )

# %%
print(report(model))
# Out:
# We fitted a logistic model (estimated using fREML and perf optimizer) to
# predict correct_prediction with log_model_size, text_length,
# non_text_prompt_length, model_family, task, sd_prompting and dataset (formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
# model_family + task + sd_prompting + log_model_size:sd_prompting +
# text_length:sd_prompting + non_text_prompt_length:sd_prompting +
# model_family:sd_prompting + task:sd_prompting + s(dataset, bs = "re")). The
# model's explanatory power is weak (R2 = 0.12). The model's intercept,
# corresponding to log_model_size = 0, text_length = 0, non_text_prompt_length =
# 0, model_family = Flan-UL, task = hatespeech, sd_prompting = 0 and dataset =
# diaz, is at -0.69 (95% CI [-1.26, -0.13], p = 0.017). Within this model:
#
#   - The effect of log model size is statistically non-significant and positive
# (beta = 0.02, 95% CI [-1.97e-03, 0.04], p = 0.079; Std. beta = 0.02, 95% CI
# [-1.78e-03, 0.03])
#   - The effect of text length is statistically significant and positive (beta =
# 1.29e-04, 95% CI [2.91e-05, 2.28e-04], p = 0.011; Std. beta = 0.02, 95% CI
# [3.89e-03, 0.03])
#   - The effect of non text prompt length is statistically non-significant and
# negative (beta = -8.38e-04, 95% CI [-2.64e-03, 9.65e-04], p = 0.362; Std. beta
# = -0.06, 95% CI [-0.20, 0.07])
#   - The effect of model family [Dolly-V2] is statistically significant and
# negative (beta = -0.12, 95% CI [-0.18, -0.06], p < .001; Std. beta = -0.12, 95%
# CI [-0.18, -0.06])
#   - The effect of model family [Flan-T5] is statistically significant and
# positive (beta = 0.21, 95% CI [0.15, 0.27], p < .001; Std. beta = 0.21, 95% CI
# [0.15, 0.27])
#   - The effect of model family [InstructGPT] is statistically significant and
# positive (beta = 1.66, 95% CI [1.58, 1.74], p < .001; Std. beta = 1.66, 95% CI
# [1.58, 1.74])
#   - The effect of model family [OPT-IML] is statistically significant and
# positive (beta = 1.26, 95% CI [1.19, 1.32], p < .001; Std. beta = 1.26, 95% CI
# [1.19, 1.32])
#   - The effect of model family [Tk-Instruct] is statistically significant and
# positive (beta = 0.79, 95% CI [0.72, 0.85], p < .001; Std. beta = 0.79, 95% CI
# [0.72, 0.85])
#   - The effect of task [sentiment] is statistically significant and negative
# (beta = -1.63, 95% CI [-2.42, -0.83], p < .001; Std. beta = -1.63, 95% CI
# [-2.42, -0.83])
#   - The effect of task [stance] is statistically non-significant and negative
# (beta = -0.29, 95% CI [-0.94, 0.36], p = 0.379; Std. beta = -0.29, 95% CI
# [-0.94, 0.36])
#   - The effect of task [toxicity] is statistically non-significant and negative
# (beta = -0.11, 95% CI [-0.75, 0.54], p = 0.743; Std. beta = -0.11, 95% CI
# [-0.75, 0.54])
#   - The effect of sd prompting [1] is statistically significant and positive
# (beta = 1.32, 95% CI [0.94, 1.70], p < .001; Std. beta = 0.22, 95% CI [-0.03,
# 0.46])
#   - The effect of log model size × sd prompting [1] is statistically significant
# and negative (beta = -0.08, 95% CI [-0.10, -0.05], p < .001; Std. beta = -0.07,
# 95% CI [-0.09, -0.04])
#   - The effect of text length × sd prompting [1] is statistically non-significant
# and positive (beta = 1.19e-04, 95% CI [-2.05e-05, 2.58e-04], p = 0.095; Std.
# beta = 0.02, 95% CI [-2.75e-03, 0.03])
#   - The effect of non text prompt length × sd prompting [1] is statistically
# significant and negative (beta = -1.71e-03, 95% CI [-2.36e-03, -1.06e-03], p <
# .001; Std. beta = -0.13, 95% CI [-0.18, -0.08])
#   - The effect of model family [Dolly-V2] × sd prompting [1] is statistically
# significant and negative (beta = -0.22, 95% CI [-0.31, -0.13], p < .001; Std.
# beta = -0.22, 95% CI [-0.31, -0.13])
#   - The effect of model family [Flan-T5] × sd prompting [1] is statistically
# significant and negative (beta = -0.26, 95% CI [-0.35, -0.17], p < .001; Std.
# beta = -0.26, 95% CI [-0.35, -0.17])
#   - The effect of model family [InstructGPT] × sd prompting [1] is statistically
# non-significant and positive (beta = 0.06, 95% CI [-0.05, 0.17], p = 0.277;
# Std. beta = 0.06, 95% CI [-0.05, 0.17])
#   - The effect of model family [OPT-IML] × sd prompting [1] is statistically
# non-significant and positive (beta = 0.01, 95% CI [-0.08, 0.10], p = 0.790;
# Std. beta = 0.01, 95% CI [-0.08, 0.10])
#   - The effect of model family [Tk-Instruct] × sd prompting [1] is statistically
# significant and negative (beta = -0.20, 95% CI [-0.28, -0.11], p < .001; Std.
# beta = -0.20, 95% CI [-0.28, -0.11])
#   - The effect of task [sentiment] × sd prompting [1] is statistically
# significant and positive (beta = 0.58, 95% CI [0.50, 0.65], p < .001; Std. beta
# = 0.58, 95% CI [0.50, 0.65])
#   - The effect of task [stance] × sd prompting [1] is statistically significant
# and positive (beta = 0.17, 95% CI [0.11, 0.22], p < .001; Std. beta = 0.17, 95%
# CI [0.11, 0.22])
#   - The effect of task [toxicity] × sd prompting [1] is statistically significant
# and negative (beta = -0.06, 95% CI [-0.10, -8.25e-03], p = 0.021; Std. beta =
# -0.06, 95% CI [-0.10, -8.25e-03])
#   - The effect of Smooth term (dataset) is statistically significant and NA (beta
# = , p < .001; Std. beta = , )
#
# Standardized parameters were obtained by fitting the model on a standardized
# version of the dataset.

# %%
print(xtable(model_anova$pTerms.table))
# Out:
# % latex table generated in R 4.2.3 by xtable 1.8-4 package
# % Sat Sep  9 21:00:24 2023
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrr}
#   \hline
#  & df & Chi.sq & p-value \\
#   \hline
# log\_model\_size & 1.00 & 3.09 & 0.08 \\
#   text\_length & 1.00 & 6.42 & 0.01 \\
#   non\_text\_prompt\_length & 1.00 & 0.83 & 0.36 \\
#   model\_family & 5.00 & 6470.73 & 0.00 \\
#   task & 3.00 & 18.31 & 0.00 \\
#   sd\_prompting & 1.00 & 45.40 & 0.00 \\
#   log\_model\_size:sd\_prompting & 1.00 & 30.04 & 0.00 \\
#   text\_length:sd\_prompting & 1.00 & 2.79 & 0.09 \\
#   non\_text\_prompt\_length:sd\_prompting & 1.00 & 26.84 & 0.00 \\
#   model\_family:sd\_prompting & 5.00 & 101.29 & 0.00 \\
#   task:sd\_prompting & 3.00 & 309.46 & 0.00 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
wald_gam(model, comp=list(model_family=levels(data$model_family), sd_prompting=1))
# Out:
# Wald test
# -----
# model: correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + sd_prompting + log_model_size:sd_prompting +
#     text_length:sd_prompting + non_text_prompt_length:sd_prompting +
#     model_family:sd_prompting + task:sd_prompting + s(dataset,
#     bs = "re")
#
# Parametric effects:
#                           (Intercept)                        log_model_size
#                         -0.6916380299                          0.0171165234
#                           text_length                non_text_prompt_length
#                          0.0001285325                         -0.0008382987
#                  model_familyDolly-V2                   model_familyFlan-T5
#                         -0.1211672255                          0.2093536270
#               model_familyInstructGPT                   model_familyOPT-IML
#                          1.6594805064                          1.2569675286
#               model_familyTk-Instruct                         tasksentiment
#                          0.7873508919                         -1.6295032693
#                            taskstance                          tasktoxicity
#                         -0.2918683390                         -0.1076623834
#                         sd_prompting1          log_model_size:sd_prompting1
#                          1.3186087935                         -0.0756515722
#             text_length:sd_prompting1  non_text_prompt_length:sd_prompting1
#                          0.0001189604                         -0.0017091789
#    model_familyDolly-V2:sd_prompting1     model_familyFlan-T5:sd_prompting1
#                         -0.2201703881                         -0.2635160578
# model_familyInstructGPT:sd_prompting1     model_familyOPT-IML:sd_prompting1
#                          0.0595277865                          0.0123130820
# model_familyTk-Instruct:sd_prompting1           tasksentiment:sd_prompting1
#                         -0.1951038945                          0.5750100557
#              taskstance:sd_prompting1            tasktoxicity:sd_prompting1
#                          0.1673689899                         -0.0557174587
#
# Null hypothesis =  0
#
# Comparing InstructGPT.1 with Tk-Instruct.1 (hatespeech):
# 	X2(1.000) = 971.242, p < 2e-16 ***
#
# Comparing OPT-IML.1 with Tk-Instruct.1 (hatespeech):
# 	X2(1.000) = 909.658, p < 2e-16 ***
#
# Comparing InstructGPT.1 with OPT-IML.1 (hatespeech):
# 	X2(1.000) = 170.809, p < 2e-16 ***
#
# Comparing Flan-UL.1 with Dolly-V2.1 (hatespeech):
# 	X2(1.000) = 105.522, p < 2e-16 ***
#
# Comparing Flan-UL.1 with Flan-T5.1 (hatespeech):
# 	X2(1.000) = 2.805, p = 0.094 .
#
# Comparing Dolly-V2.1 with Flan-T5.1 (hatespeech):
# 	X2(1.000) = 144.773, p < 2e-16 ***
#
# Comparing Flan-UL.1 with Tk-Instruct.1 (hatespeech):
# 	X2(1.000) = 342.935, p < 2e-16 ***
#
# Comparing Flan-T5.1 with Tk-Instruct.1 (hatespeech):
# 	X2(1.000) = 1571.796, p < 2e-16 ***
#
# Comparing Dolly-V2.1 with Tk-Instruct.1 (hatespeech):
# 	X2(1.000) = 1592.342, p < 2e-16 ***
#
# Comparing Flan-UL.1 with OPT-IML.1 (hatespeech):
# 	X2(1.000) = 1521.202, p < 2e-16 ***
#
# Comparing Flan-T5.1 with OPT-IML.1 (hatespeech):
# 	X2(1.000) = 3315.284, p < 2e-16 ***
#
# Comparing Dolly-V2.1 with OPT-IML.1 (hatespeech):
# 	X2(1.000) = 3881.856, p < 2e-16 ***
#
# Comparing Flan-UL.1 with InstructGPT.1 (hatespeech):
# 	X2(1.000) = 1987.492, p < 2e-16 ***
#
# Comparing Flan-T5.1 with InstructGPT.1 (hatespeech):
# 	X2(1.000) = 2355.226, p < 2e-16 ***
#
# Comparing Dolly-V2.1 with InstructGPT.1 (hatespeech):
# 	X2(1.000) = 3428.799, p < 2e-16 ***

# %%
wald_gam(model, comp=list(task=levels(data$task), sd_prompting=1))
# Out:
# Wald test
# -----
# model: correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + sd_prompting + log_model_size:sd_prompting +
#     text_length:sd_prompting + non_text_prompt_length:sd_prompting +
#     model_family:sd_prompting + task:sd_prompting + s(dataset,
#     bs = "re")
#
# Parametric effects:
#                           (Intercept)                        log_model_size
#                         -0.6916380299                          0.0171165234
#                           text_length                non_text_prompt_length
#                          0.0001285325                         -0.0008382987
#                  model_familyDolly-V2                   model_familyFlan-T5
#                         -0.1211672255                          0.2093536270
#               model_familyInstructGPT                   model_familyOPT-IML
#                          1.6594805064                          1.2569675286
#               model_familyTk-Instruct                         tasksentiment
#                          0.7873508919                         -1.6295032693
#                            taskstance                          tasktoxicity
#                         -0.2918683390                         -0.1076623834
#                         sd_prompting1          log_model_size:sd_prompting1
#                          1.3186087935                         -0.0756515722
#             text_length:sd_prompting1  non_text_prompt_length:sd_prompting1
#                          0.0001189604                         -0.0017091789
#    model_familyDolly-V2:sd_prompting1     model_familyFlan-T5:sd_prompting1
#                         -0.2201703881                         -0.2635160578
# model_familyInstructGPT:sd_prompting1     model_familyOPT-IML:sd_prompting1
#                          0.0595277865                          0.0123130820
# model_familyTk-Instruct:sd_prompting1           tasksentiment:sd_prompting1
#                         -0.1951038945                          0.5750100557
#              taskstance:sd_prompting1            tasktoxicity:sd_prompting1
#                          0.1673689899                         -0.0557174587
#
# Null hypothesis =  0
#
# Comparing hatespeech.1 with sentiment.1 (Flan-T5):
# 	X2(1.000) = 6.782, p = 0.009 **
#
# Comparing hatespeech.1 with toxicity.1 (Flan-T5):
# 	X2(1.000) = 0.247, p = 0.619
#
# Comparing hatespeech.1 with stance.1 (Flan-T5):
# 	X2(1.000) = 0.141, p = 0.707
#
# Comparing stance.1 with toxicity.1 (Flan-T5):
# 	X2(1.000) = 0.014, p = 0.906
#
# Comparing sentiment.1 with toxicity.1 (Flan-T5):
# 	X2(1.000) = 4.858, p = 0.028 *
#
# Comparing sentiment.1 with stance.1 (Flan-T5):
# 	X2(1.000) = 5.326, p = 0.021 *

# %%
# shift <- coef(model)[1]
# plot(model,
#     #select=i,
#     pages = 0,
#     rug = TRUE,
#     residuals = FALSE,
#     shade = TRUE,
#     #col="blue",
#     shade.col = "gray90",
#     seWithMean = TRUE,
#     shift=shift,
#     scale=0,
#     all.terms = TRUE,
#     scheme = 2,
#     contour.col = "black",
#     #lwd=3,
#     #main=new_title,
#     #xlab=covariates2plottitles[[all_plots[[i]]$xlab]],
#     #ylab=new_y_label
# )

# %%
# plot_smooth(model, view="log_model_size",
#             cond=list(sd_prompting=c(0)),
#             col="red",
#             rug=FALSE,
#             #add=TRUE,
#             rm.ranef=TRUE)
# plot_smooth(model, view="log_model_size",
#             cond=list(sd_prompting=c(1)),
#             col="blue",
#             rug=FALSE,
#             add=TRUE,
#             rm.ranef=TRUE)

# %%
# plot_diff(model, view="log_model_size",
#             comp=list(sd_prompting=c(1,0)),
#             col="red",
#             rug=FALSE,
#             #add=TRUE,
#             rm.ranef=TRUE)

# %%
# plot_diff(model, view="text_length",
#             comp=list(sd_prompting=c(1,0)),
#             col="red",
#             rug=FALSE,
#             #add=TRUE,
#             rm.ranef=TRUE)

# %%
# contrasts
# wald_gam(model, comp=list(sd_prompting=levels(data$sd_prompting), model_family="Flan-UL"))
# wald_gam(model, comp=list(sd_prompting=levels(data$sd_prompting), model_family="Flan-T5"))
# wald_gam(model, comp=list(sd_prompting=levels(data$sd_prompting), model_family="InstructGPT"))
# wald_gam(model, comp=list(sd_prompting=levels(data$sd_prompting), model_family="OPT-IML"))
# wald_gam(model, comp=list(sd_prompting=levels(data$sd_prompting), model_family="Tk-Instruct"))
# wald_gam(model, comp=list(sd_prompting=levels(data$sd_prompting), model_family="Dolly-V2"))

# %%
#diff <- get_difference(model, comp=list(sd_prompting=levels(data$sd_prompting)), cond=list(model_family="Flan-UL"))
#print(diff)

# %% [markdown]
# ## Analysis IV: Disagreement Prediction

# %%
data = read.csv('data/disagreement_detection.tsv',sep='\t')

# Decode B and M size strings, convert to millions
data$model_size <- str_replace(data$model_size, "175B", "175000000000")
data$model_size <- str_replace(data$model_size, "250M", "250000000")
data$model_size <- str_replace(data$model_size, "780M", "780000000")
data$model_size <- str_replace(data$model_size, "11B", "11000000000")
data$model_size <- str_replace(data$model_size, "20B", "20000000000")
data$model_size <- str_replace(data$model_size, "1.3B", "1300000000")
data$model_size <- str_replace(data$model_size, "30B", "30000000000")
data$model_size <- str_replace(data$model_size, "2.8B", "2800000000")
data$model_size <- str_replace(data$model_size, "6.9B", "6900000000")
data$model_size <- str_replace(data$model_size, "12B", "12000000000")
data$model_size <- str_replace(data$model_size, "3B", "3000000000")
data$model_size <- str_replace(data$model_size, "80M", "80000000")
data$model_size <- as.numeric(data$model_size)
data$log_model_size <- log10(data$model_size)
data$non_text_prompt_length <- data$mean_prompt_length - data$text_length
# set data types
data <- as.data.frame(unclass(data),
                      stringsAsFactors = TRUE)
data$model_family <- relevel(data$model_family, ref="Flan-UL")
head(data)
summary(data)
# Out:
#   model_name       model_family model_size task     dataset
# 1 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 2 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 3 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 4 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 5 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
# 6 text-davinci-003 InstructGPT  1.75e+11   toxicity diverse_perspectives
#   instance_id                     mean_prompt_length std_prompt_length
# 1 toxicity_diverse_perspectives_0 344.0               6.723095
# 2 toxicity_diverse_perspectives_1 385.8              15.778466
# 3 toxicity_diverse_perspectives_2 383.2              21.958142
# 4 toxicity_diverse_perspectives_3 420.0              14.505171
# 5 toxicity_diverse_perspectives_4 388.2              19.260322
# 6 toxicity_diverse_perspectives_5 428.6              14.677875
#   text_length correct_prediction original_dispersion prompting_dispersion
# 1 31          0                  0.7                 0
# 2 49          0                  0.7                 0
# 3 57          0                  0.4                 0
# 4 94          0                  0.8                 0
# 5 50          0                  0.8                 0
# 6 95          0                  0.4                 0
#   log_model_size non_text_prompt_length
# 1 11.24304       313.0
# 2 11.24304       336.8
# 3 11.24304       326.2
# 4 11.24304       326.0
# 5 11.24304       338.2
# 6 11.24304       333.6
#                              model_name         model_family
#  allenai-tk-instruct-11b-def-pos  : 6999   Flan-UL    : 6999
#  allenai-tk-instruct-3b-def-pos   : 6999   Dolly-V2   :20997
#  allenai-tk-instruct-base-def-pos : 6999   Flan-T5    :34995
#  allenai-tk-instruct-large-def-pos: 6999   InstructGPT: 6999
#  allenai-tk-instruct-small-def-pos: 6999   OPT-IML    :13998
#  databricks-dolly-v2-12b          : 6999   Tk-Instruct:34995
#  (Other)                          :76989
#    model_size                task                       dataset
#  Min.   :8.000e+07   hatespeech:34000   diaz                :17000
#  1st Qu.:7.800e+08   sentiment :17000   diverse_perspectives:17000
#  Median :3.000e+09   stance    :33983   ghc                 :17000
#  Mean   :1.637e+10   toxicity  :34000   gwsd                :16983
#  3rd Qu.:1.100e+10                      jigsaw              :17000
#  Max.   :1.750e+11                      semeval2016t6       :17000
#                                         twitter             :17000
#              instance_id     mean_prompt_length std_prompt_length
#  hatespeech_ghc_0  :    17   Min.   : 238.2     Min.   : 0.6325
#  hatespeech_ghc_1  :    17   1st Qu.: 376.0     1st Qu.: 7.6837
#  hatespeech_ghc_10 :    17   Median : 416.2     Median :11.3031
#  hatespeech_ghc_100:    17   Mean   : 436.3     Mean   :12.0192
#  hatespeech_ghc_101:    17   3rd Qu.: 454.5     3rd Qu.:16.0947
#  hatespeech_ghc_102:    17   Max.   :1682.2     Max.   :28.7931
#  (Other)           :118881
#   text_length     correct_prediction original_dispersion prompting_dispersion
#  Min.   :   2.0   Min.   :0.0000     Min.   :0.0000      Min.   :0.0000
#  1st Qu.:  66.0   1st Qu.:0.0000     1st Qu.:0.0000      1st Qu.:0.0000
#  Median : 104.0   Median :0.0000     Median :0.4000      Median :0.0000
#  Mean   : 132.5   Mean   :0.4888     Mean   :0.3383      Mean   :0.1539
#  3rd Qu.: 137.0   3rd Qu.:1.0000     3rd Qu.:0.6000      3rd Qu.:0.4000
#  Max.   :1343.0   Max.   :1.0000     Max.   :1.0000      Max.   :1.0000
#
#  log_model_size   non_text_prompt_length
#  Min.   : 7.903   Min.   :227.2
#  1st Qu.: 8.892   1st Qu.:268.6
#  Median : 9.477   Median :307.4
#  Mean   : 9.407   Mean   :303.8
#  3rd Qu.:10.041   3rd Qu.:331.2
#  Max.   :11.243   Max.   :383.4

# %%
# correct_prediction means correct disagreement prediction here
model_formula <- correct_prediction ~   log_model_size +
                                        text_length +
                                        non_text_prompt_length +
                                        model_family +
                                        task +
                                        # log_model_size:text_length +
                                        # log_model_size:non_text_prompt_length +
                                        # log_model_size:model_family +
                                        # log_model_size:task +
                                        # text_length:non_text_prompt_length +
                                        # text_length:model_family +
                                        # text_length:task +
                                        # non_text_prompt_length:model_family +
                                        # non_text_prompt_length:task +
                                        # model_family:task +
                                        s(dataset, bs = "re")
     
set.seed(0)
model <- bam(model_formula,
             data = data,
             family = binomial("logit"), # probit might also make sense: https://stats.stackexchange.com/questions/207625/how-to-choose-between-logit-probit-or-linear-probability-model
             method = "fREML",
             discrete = TRUE,
             select = TRUE,
             nthreads=12
             )


# Save the model and its dependencies
saveRDS(model, "models/disagreement.rds")
dependencies = c("mgcv")
file_obj <- file("models/disagreement.dep")
writeLines(dependencies, file_obj)
close(file_obj)

# Reports
summary(model)
# Out:
# Family: binomial
# Link function: logit
#
# Formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + s(dataset, bs = "re")
#
# Parametric coefficients:
#                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)             -2.219e+00  4.128e-01  -5.375 7.68e-08 ***
# log_model_size           2.240e-01  9.431e-03  23.755  < 2e-16 ***
# text_length             -2.717e-04  5.056e-05  -5.374 7.72e-08 ***
# non_text_prompt_length   7.359e-04  8.768e-04   0.839   0.4013
# model_familyDolly-V2     5.818e-01  3.028e-02  19.212  < 2e-16 ***
# model_familyFlan-T5      5.251e-01  2.997e-02  17.519  < 2e-16 ***
# model_familyInstructGPT  2.940e-02  3.599e-02   0.817   0.4140
# model_familyOPT-IML      3.041e-01  3.065e-02   9.922  < 2e-16 ***
# model_familyTk-Instruct  3.956e-01  2.995e-02  13.207  < 2e-16 ***
# tasksentiment           -1.065e+00  5.501e-01  -1.936   0.0529 .
# taskstance              -9.314e-01  4.499e-01  -2.070   0.0384 *
# tasktoxicity            -4.040e-01  4.480e-01  -0.902   0.3672
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Approximate significance of smooth terms:
#              edf Ref.df Chi.sq p-value
# s(dataset) 2.976      5  138.1  <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# R-sq.(adj) =  0.0615   Deviance explained = 4.52%
# fREML = 1.8811e+05  Scale est. = 1         n = 118983

# %%
# Wald tests (same as summary() for smooth terms, but different output for parametric terms)
set.seed(0)
model_anova <- anova(model)
print(model_anova)
# Out:
# Family: binomial
# Link function: logit
#
# Formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + s(dataset, bs = "re")
#
# Parametric Terms:
#                        df  Chi.sq  p-value
# log_model_size          1 564.285  < 2e-16
# text_length             1  28.876 7.72e-08
# non_text_prompt_length  1   0.704    0.401
# model_family            5 579.842  < 2e-16
# task                    3   5.921    0.116
#
# Approximate significance of smooth terms:
#              edf Ref.df Chi.sq p-value
# s(dataset) 2.976  5.000  138.1  <2e-16

# %%
print(xtable(model_anova$pTerms.table))
# Out:
# % latex table generated in R 4.2.3 by xtable 1.8-4 package
# % Sat Sep  9 23:08:15 2023
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrr}
#   \hline
#  & df & Chi.sq & p-value \\
#   \hline
# log\_model\_size & 1.00 & 564.29 & 0.00 \\
#   text\_length & 1.00 & 28.88 & 0.00 \\
#   non\_text\_prompt\_length & 1.00 & 0.70 & 0.40 \\
#   model\_family & 5.00 & 579.84 & 0.00 \\
#   task & 3.00 & 5.92 & 0.12 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
print(report(model))
# Out:
# We fitted a logistic model (estimated using fREML and perf optimizer) to
# predict correct_prediction with log_model_size, text_length,
# non_text_prompt_length, model_family, task and dataset (formula:
# correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
# model_family + task + s(dataset, bs = "re")). The model's explanatory power is
# weak (R2 = 0.06). The model's intercept, corresponding to log_model_size = 0,
# text_length = 0, non_text_prompt_length = 0, model_family = Flan-UL, task =
# hatespeech and dataset = diaz, is at -2.22 (95% CI [-3.03, -1.41], p < .001).
# Within this model:
#
#   - The effect of log model size is statistically significant and positive (beta
# = 0.22, 95% CI [0.21, 0.24], p < .001; Std. beta = 0.20, 95% CI [0.19, 0.22])
#   - The effect of text length is statistically significant and negative (beta =
# -2.72e-04, 95% CI [-3.71e-04, -1.73e-04], p < .001; Std. beta = -0.04, 95% CI
# [-0.05, -0.02])
#   - The effect of non text prompt length is statistically non-significant and
# positive (beta = 7.36e-04, 95% CI [-9.83e-04, 2.45e-03], p = 0.401; Std. beta =
# 0.03, 95% CI [-0.04, 0.09])
#   - The effect of model family [Dolly-V2] is statistically significant and
# positive (beta = 0.58, 95% CI [0.52, 0.64], p < .001; Std. beta = 0.58, 95% CI
# [0.52, 0.64])
#   - The effect of model family [Flan-T5] is statistically significant and
# positive (beta = 0.53, 95% CI [0.47, 0.58], p < .001; Std. beta = 0.53, 95% CI
# [0.47, 0.58])
#   - The effect of model family [InstructGPT] is statistically non-significant and
# positive (beta = 0.03, 95% CI [-0.04, 0.10], p = 0.414; Std. beta = 0.03, 95%
# CI [-0.04, 0.10])
#   - The effect of model family [OPT-IML] is statistically significant and
# positive (beta = 0.30, 95% CI [0.24, 0.36], p < .001; Std. beta = 0.30, 95% CI
# [0.24, 0.36])
#   - The effect of model family [Tk-Instruct] is statistically significant and
# positive (beta = 0.40, 95% CI [0.34, 0.45], p < .001; Std. beta = 0.40, 95% CI
# [0.34, 0.45])
#   - The effect of task [sentiment] is statistically non-significant and negative
# (beta = -1.06, 95% CI [-2.14, 0.01], p = 0.053; Std. beta = -1.06, 95% CI
# [-2.14, 0.01])
#   - The effect of task [stance] is statistically significant and negative (beta =
# -0.93, 95% CI [-1.81, -0.05], p = 0.038; Std. beta = -0.93, 95% CI [-1.81,
# -0.05])
#   - The effect of task [toxicity] is statistically non-significant and negative
# (beta = -0.40, 95% CI [-1.28, 0.47], p = 0.367; Std. beta = -0.40, 95% CI
# [-1.28, 0.47])
#   - The effect of Smooth term (dataset) is statistically significant and NA (beta
# = , p < .001; Std. beta = , )
#
# Standardized parameters were obtained by fitting the model on a standardized
# version of the dataset.

# %%
wald_gam(model, comp=list(model_family=levels(data$model_family)))
# Out:
# Wald test
# -----
# model: correct_prediction ~ log_model_size + text_length + non_text_prompt_length +
#     model_family + task + s(dataset, bs = "re")
#
# Parametric effects:
#             (Intercept)          log_model_size             text_length
#           -2.2187640764            0.2240187011           -0.0002717079
#  non_text_prompt_length    model_familyDolly-V2     model_familyFlan-T5
#            0.0007358980            0.5817810668            0.5251172520
# model_familyInstructGPT     model_familyOPT-IML model_familyTk-Instruct
#            0.0294036107            0.3040646506            0.3955996987
#           tasksentiment              taskstance            tasktoxicity
#           -1.0648120740           -0.9313697587           -0.4040103149
#
# Null hypothesis =  0
#
# Comparing Dolly-V2 with InstructGPT (hatespeech):
# 	X2(1.000) = 284.390, p < 2e-16 ***
#
# Comparing Flan-T5 with InstructGPT (hatespeech):
# 	X2(1.000) = 205.568, p < 2e-16 ***
#
# Comparing Dolly-V2 with OPT-IML (hatespeech):
# 	X2(1.000) = 132.056, p < 2e-16 ***
#
# Comparing Flan-T5 with OPT-IML (hatespeech):
# 	X2(1.000) = 99.667, p < 2e-16 ***
#
# Comparing Dolly-V2 with Tk-Instruct (hatespeech):
# 	X2(1.000) = 74.620, p < 2e-16 ***
#
# Comparing Flan-T5 with Tk-Instruct (hatespeech):
# 	X2(1.000) = 68.788, p < 2e-16 ***
#
# Comparing Dolly-V2 with Flan-T5 (hatespeech):
# 	X2(1.000) = 6.908, p = 0.009 **
#
# Comparing Flan-UL with InstructGPT (hatespeech):
# 	X2(1.000) = 0.667, p = 0.414
#
# Comparing OPT-IML with Tk-Instruct (hatespeech):
# 	X2(1.000) = 17.104, p = 3.54e-05 ***
#
# Comparing InstructGPT with OPT-IML (hatespeech):
# 	X2(1.000) = 69.011, p < 2e-16 ***
#
# Comparing Flan-UL with OPT-IML (hatespeech):
# 	X2(1.000) = 98.439, p < 2e-16 ***
#
# Comparing InstructGPT with Tk-Instruct (hatespeech):
# 	X2(1.000) = 112.401, p < 2e-16 ***
#
# Comparing Flan-UL with Tk-Instruct (hatespeech):
# 	X2(1.000) = 174.415, p < 2e-16 ***
#
# Comparing Flan-UL with Flan-T5 (hatespeech):
# 	X2(1.000) = 306.911, p < 2e-16 ***
#
# Comparing Flan-UL with Dolly-V2 (hatespeech):
# 	X2(1.000) = 369.088, p < 2e-16 ***
